# %%
import joblib

# %%
DTC = joblib.load("../model/decision_tree.pkl")

# %%
DTC.predict([[4.0, 0.97, 77]])
# Out:
# /Users/alexandrekouakou/Downloads/AI_and_Data_Science/think_as_a_data_scientist/PROJECTS/cab315/D38/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['A'], dtype=object)
