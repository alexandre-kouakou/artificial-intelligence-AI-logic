# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/alexandrekouakou/student-performance-dataset")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Dataset URL: https://www.kaggle.com/datasets/alexandrekouakou/student-performance-dataset
# ...
# 100%|██████████| 2.69k/2.69k [00:00<00:00, 3.06MB/s]
